# %%
import pandas as pd

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_excel(r'C:\Users\31260\Desktop\PID500.xlsx')
data = df.head(201)

# %%
plt.plot(data['t'],data['T'])

plt.xlabel('t/s', fontsize=14)
plt.ylabel('$T/^{\circ} C$', fontsize=14)

plt.hlines(32, 100, 310, linestyles = 'dashed', colors = 'orange')
plt.ylim(31.4,32.6)
plt.xlim(100,310)
plt.grid()
print(' 比例增益：{}\n 积分时间：{}min\n 微分时间：{}min\n'.format(600,0.142,0.035))
plt.show()
# Out:
#  比例增益：600
#  积分时间：0.142min
#  微分时间：0.035min
