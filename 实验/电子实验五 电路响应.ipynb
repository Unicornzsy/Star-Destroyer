# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
rcw1 = pd.read_csv(r'C:\Users\31260\Desktop\电子实验\实验五 电路测量\RC微分2.4k(30Hz)\RCW1.csv')
data1 = rcw1.head(1200)
rcw2 = pd.read_csv(r'C:\Users\31260\Desktop\电子实验\实验五 电路测量\RC微分5.1k(30Hz)\新建文件1.csv')
data2 = rcw2.head(1200)

# %%
plt.plot(data1['X'][1:500], data1['CH1'][1:500])
plt.plot(data2['X'][1:500], data2['CH1'][1:500])

plt.show()

# %%
rcj1 = pd.read_csv(r'C:\Users\31260\Desktop\电子实验\实验五 电路测量\RC积分3k\新建文件1.csv')
data1 = rcj1.head(1200)
rcj2 = pd.read_csv(r'C:\Users\31260\Desktop\电子实验\实验五 电路测量\RC积分5.1k\新建文件1.csv')
data2 = rcj2.head(1200)

# %%
plt.plot(data1['X'][1:1200:50], data1['CH1'][1:1200:50], label = '3k')
plt.plot(data2['X'][1:1200:50], data2['CH1'][1:1200:50], label = '5.1k')

plt.grid()
plt.legend(frameon = False)
plt.show()
