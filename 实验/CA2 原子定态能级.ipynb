# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\标准（0.2）.xlsx")
data = df.head(453)

# %%
plot(data['V'][:] ,data['a'][:] ,c = 'cyan')


title(r'$manual \ measuring (every \ 0.2V \ a \ point)$')
xlim(0, 90)
ylim(0, 210)
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
#plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
plot(data['V'][:] ,data['a'][:] ,c = 'cyan')
plt.scatter(data['V'][101],data['a'][101], s = 10, label='({},{:.2f})'.format(data['V'][101],data['a'][101]))
plt.scatter(data['V'][158],data['a'][158], s = 10, label='({},{:.2f})'.format(data['V'][158],data['a'][158]))
plt.scatter(data['V'][214],data['a'][214], s = 10, label='({},{:.2f})'.format(data['V'][214],data['a'][214]))
plt.scatter(data['V'][271],data['a'][271], s = 10, label='({},{:.2f})'.format(data['V'][271],data['a'][271]))
plt.scatter(data['V'][330],data['a'][330], s = 10, label='({},{:.2f})'.format(data['V'][330],data['a'][330]))
plt.scatter(data['V'][391],data['a'][391], s = 10, label='({},{:.2f})'.format(data['V'][391],data['a'][391]))


title(r'$manual \ measuring (the \ peaks)$')
xlim(0, 90)
ylim(0, 210)
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
plot(data['V'][:] ,data['a'][:] ,c = 'cyan')
plt.scatter(data['V'][127],data['a'][127], s = 10, label='({},{:.2f})'.format(data['V'][127],data['a'][127]))
plt.scatter(data['V'][185],data['a'][185], s = 10, label='({},{:.2f})'.format(data['V'][185],data['a'][185]))
plt.scatter(data['V'][242],data['a'][242], s = 10, label='({},{:.2f})'.format(data['V'][242],data['a'][242]))
plt.scatter(data['V'][300],data['a'][300], s = 10, label='({},{:.2f})'.format(data['V'][300],data['a'][300]))
plt.scatter(data['V'][359],data['a'][359], s = 10, label='({},{:.2f})'.format(data['V'][359],data['a'][359]))
plt.scatter(data['V'][420],data['a'][420], s = 10, label='({},{:.2f})'.format(data['V'][420],data['a'][420]))


title(r'$manual \ measuring (the \ valleys)$')
xlim(0, 90)
ylim(0, 210)
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
df8 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\手动峰.xlsx")
data8 = df8.head(100)
df9 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\手动谷.xlsx")
data9 = df9.head(100)

# %%
plot(data['V'][:] ,data['a'][:] ,c = 'cyan', label = r'$per \ 0.2V \ a \ point$')
plot(data8['V'][:] ,data8['A'][:]*1.74 ,c = 'orange', label = r'$per \ 0.1V \ a \ point(peak)$')
plot(data9['V'][:] ,data9['A'][:] ,c = 'red', label = r'$per \ 0.1V \ a \ point(valley)$')

plt.scatter(data8['V'][19], data8['A'][19]*1.74, marker =  '^', s = 10, c = 'k')
plt.annotate(r'$({},{:.3f})$'.format(data8['V'][19], data8['A'][19]*1.74), xytext = (30, 125), xy=(data8['V'][19], data8['A'][19]*1.74),arrowprops={'shrink':0.1, 'width':1, 'facecolor':'gray'})

plt.scatter(data9['V'][38], data9['A'][38], marker =  '^', s = 10, c = 'k')
plt.annotate(r'$({},{:.3f})$'.format(data9['V'][38], data9['A'][38]), xytext = (60, 25), xy=(data9['V'][38], data9['A'][38]),arrowprops={'shrink':0.1, 'width':1, 'facecolor':'gray'})

xlim(0, 90)
ylim(0, 210)
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
plot(data1['V'][:] ,data1['A'][:] ,c = 'blue')


title(r'$I_{P}-V_{G_2K}$')
xlim(0, 90)
ylim(0, 90)

plt.scatter(data1['V'][14], data1['A'][14], marker =  '^', s = 10, c = 'k')
plt.annotate(r'$U_s$', xytext = (10, 20), xy=(data1['V'][14], data1['A'][14]),arrowprops={'shrink':0.1, 'width':1, 'facecolor':'cyan'})

plt.scatter(data1['V'][91], data1['A'][91], marker =  '^', s = 10, c = 'k')
plt.annotate(r'$I_{pmax}$', xytext = (75, 85), xy=(data1['V'][91], data1['A'][91]),arrowprops={'shrink':0.1, 'width':1, 'facecolor':'cyan'})


ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
#plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
df1 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\标准.xlsx")
data1 = df1.head(100)
df2 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\大一栅压.xlsx")
data2 = df2.head(100)
df3 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\小一栅压.xlsx")
data3 = df3.head(100)

# %%
plot(data1['V'][:] ,data1['A'][:] ,'k-', label = r'$V_{G_1K}=1.5V$')
plot(data2['V'][:] ,data2['A'][:] , 'orange', label = r'$V_{G_1K}=2.0V$')
plot(data3['V'][:] ,data3['A'][:] ,'b', label = r'$V_{G_1K}=1.0V$')

title(r'$Change\ V_{G_1K}$')
xlim(0, 90)
ylim(0, 150)
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.grid()
plt.legend(frameon = False)
plt.show()

# %%
plot(data1['V'][:] ,data1['A'][:] ,'k-', label = r'$V_{G_1K}=1.5V$')
plot(data2['V'][:] ,data2['A'][:]/1.4 , 'orange', label = r'$V_{G_1K}=2.0V(\times\frac{7}{5})$')
plot(data3['V'][:] ,data3['A'][:] ,'b', label = r'$V_{G_1K}=1.0V$')

title(r'$Change\ V_{G_1K}$')
xlim(0, 90)
ylim(0, 150)
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.grid()
plt.legend(frameon = False)
plt.show()

# %%
df4 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\大灯压.xlsx")
data4 = df4.head(100)
df5 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\小灯压.xlsx")
data5 = df5.head(100)

# %%
plot(data1['V'][:] ,data1['A'][:] ,'k-', label = r'$V_L=2.0V$')
plot(data4['V'][:] ,data4['A'][:] , 'orange', label = r'$V_L=2.5V$')
plot(data5['V'][:] ,data5['A'][:] ,'b', label = r'$V_L=1.5V$')

#xlim(0, 90)
#ylim(0, 150)
title(r'$Change\ V_L$')
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.grid()
plt.legend(frameon = False)
plt.show()

# %%
#plot(data1['V'][:] ,data1['A'][:] ,'k-', label = r'$V_L=2.0V$')
#plot(data4['V'][:] ,data4['A'][:] , 'orange', label = r'$V_L=2.5V$')
plot(data5['V'][:] ,data5['A'][:] ,'b', label = r'$V_L=1.5V$')

xlim(0, 90)
ylim(1, 3)

ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.grid()
plt.legend(frameon = False)
plt.show()

# %%
plot(data1['V'][:] ,data1['A'][:] ,'k-', label = r'$V_L=2.0V$')
plot(data4['V'][:] ,data4['A'][:] /20, 'orange', label = r'$V_L=2.5V(\times\frac{1}{20})$')
plot(data5['V'][:] ,data5['A'][:] *20,'b', label = r'$V_L=1.5V(\times20)$')

#xlim(0, 90)
#ylim(0, 150)
title(r'$compare\ V_L$')
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.grid()
plt.legend(frameon = False)
plt.show()

# %%
df6 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\标准（0.25）.xlsx")
data6 = df6.head(400)
df7 = pd.read_excel(r"C:\Users\31260\Desktop\基础实验\CA2原子定态能级实验\原子定态能级\标准（0.5）.xlsx")
data7 = df7.head(400)

# %%
plot(data1['V'][:] ,data1['A'][:] ,'k-', label = r'$1.00V \ per \ sample \ point$')
plot(data7['V'][:] ,data7['A'][:] , 'orange', label = r'$0.50V \ per \ sample \ point$')
plot(data6['V'][:] ,data6['A'][:] ,'b', label = r'$0.25V \ per \ sample \ point$')

#xlim(0, 90)
#ylim(0, 150)
title(r'$change \ interval$')
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.grid()
plt.legend(frameon = False)
plt.show()

# %%
plot(data1['V'][:] ,data1['A'][:] ,'k-', label = r'$1.00V \ per \ sample \ point$')
plot(data7['V'][:] ,data7['A'][:]/4*3 , 'orange', label = r'$0.50V \ per \ sample \ point(\times \frac{3}{4})$')
plot(data6['V'][:] ,data6['A'][:]/16*10 ,'b', label = r'$0.25V \ per \ sample \ point(\times \frac{5}{8})$')

#xlim(0, 90)
#ylim(0, 150)
title(r'$change \ interval$')
ylabel(r'$I/\mu A$', fontsize = 14);
xlabel(r'$U/V$', fontsize = 14);
plt.grid()
plt.legend(frameon = False)
plt.show()
