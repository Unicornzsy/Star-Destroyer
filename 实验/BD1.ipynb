# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
df1 = pd.read_excel(r'C:\Users\31260\Desktop\BD1\混沌复摆\阻尼\频率0.6000阻尼.xlsx')
data1 = df1.head(4001)

# %%
plt.plot(data1['t']-120, data1['a'])
plt.scatter(data1['t'][32]-120, data1['a'][32], c = 'k', label = '$A_0(0.66,123.912)$', s=15)
plt.scatter(data1['t'][2629]-120, data1['a'][2629], c = 'k', label = '$A_n(52.60,17.844)$', s=18)

plt.hlines(0, -5, 70, linestyle = 'dashed', colors = 'orange')

plt.xlim(-1, 70)
plt.title(r'$damped \quad vibration$')
plt.xlabel(r'$t/s$', fontsize = 14)
plt.ylabel(r'$\theta /^{\circ}$', fontsize = 14)
plt.legend(frameon = False)
plt.grid()

# %%
df2 = pd.read_excel(r'C:\Users\31260\Desktop\BD1\混沌复摆\0.5受迫\频率0.5000 受迫.xlsx')
data2 = df2.head(6001)

# %%
plt.plot(data2['t']-120, data2['a'])
#plt.scatter(data2['t'][32]-120, data2['a'][32], c = 'k', label = '$A_0(0.66,123.912)$', s=15)
#plt.scatter(data2['t'][2629]-120, data2['a'][2629], c = 'k', label = '$A_n(52.60,17.844)$', s=18)

plt.hlines(17.6, -5, 120, linestyle = 'dashed', colors = 'orange', label = r'$A_{max}=17.6$')
plt.hlines(-16.8, -5, 120, linestyle = 'dashed', colors = 'red', label = r'$A_{min}=-16.8$')
plt.xlim(-1, 120)
plt.title(r'$forced \quad vibration$')
plt.xlabel(r'$t/s$', fontsize = 14)
plt.ylabel(r'$\theta /^{\circ}$', fontsize = 14)
plt.legend(frameon = False)
plt.grid()
