# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Ux1=[0.00, 1.00, 2.00, 3.00, 4.00, 5.00]
Us1=[5.97e-4, 0.96483, 1.97689, 2.9895, 3.9813, 5.0032]
C1=list(np.array(Us1)-np.array(Ux1))

plt.plot(Ux1, C1)
plt.scatter(Ux1, C1, c = 'k')
plt.hlines(0, 0, 5, linestyles = 'dashed', colors = 'orange')
plt.ylabel(r"$\Delta U/V$", fontsize = 14)
plt.xlabel(r"$U_x/V$", fontsize = 14)

plt.title('Rough Measurement')

plt.show()

# %%
Ux2=np.linspace(0.00, 5.00, 26)
Us2=[1.799e-3, 1.76889e-1, 0.36961, 0.55827, 0.75231, 0.96456, 1.15776, 1.35759, 1.56135, 1.76188, 1.96764, 2.1701, 2.3662, 2.5541, 2.7500, 2.9541, 3.1582, 3.3635, 3.5720, 3.7779, 3.9755, 4.1800, 4.3872, 4.5961, 4.8030, 5.0033]
C2=list(np.array(Us2)-np.array(Ux2))

plt.plot(Ux2, C2, label = r'$Precision$')
plt.scatter(Ux2, C2, c = 'k')

plt.plot(Ux1, C1, label = r'$Rough$')
plt.scatter(Ux1, C1, c = 'k')

plt.hlines(0, 0, 5, linestyles = 'dashed', colors = 'purple')
plt.ylabel(r"$\Delta U/V$", fontsize = 14)
plt.xlabel(r"$U_x/V$", fontsize = 14)

plt.title(r'$5.00V \quad Voltmeter $')
plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
Ux3=np.linspace(0.00, 10.00, 26)
Us3=[1.3505e-3, 0.35937, 0.76111, 1.12080, 1.52390, 1.93605, 2.3329, 2.7259, 3.1123, 3.5400, 3.9505, 4.3454, 4.7423, 5.1322, 5.5109, 5.9112, 6.3320, 6.7256, 7.1459, 7.5471, 7.9666, 8.3497, 8.7532, 9.1906, 9.5910, 10.0047]
C3=list(np.array(Us3)-np.array(Ux3))

plt.plot(Ux3, C3)#, label = r'$Precision$'
plt.scatter(Ux3, C3, c = 'k')


plt.hlines(0, -1, 11, linestyles = 'dashed', colors = 'purple')
plt.ylabel(r"$\Delta U/V$", fontsize = 14)
plt.xlabel(r"$U_x/V$", fontsize = 14)

plt.xlim(-0.5, 10.5)
plt.title(r'$10.00V \quad Voltmeter $')
#plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
Ix1=np.linspace(0.00, 50.00, 26)
Is1=[7.5528e-4, 1.73350, 3.7140, 5.5556, 7.4247, 9.3977, 11.3183, 13.2564, 15.2551, 17.2887, 19.2534, 21.095, 23.064, 24.899, 26.770, 28.807, 30.767, 32.747, 34.799, 36.727, 38.744, 40.818, 42.753, 44.647, 46.744, 48.618]
C4=list(np.array(Is1)-np.array(Ix1))

plt.plot(Ix1, C4)
plt.scatter(Ix1, C4, c = 'k')

plt.hlines(0, -10, 60, linestyles = 'dashed', colors = 'purple')
plt.ylabel(r"$\Delta I/mA$", fontsize = 14)
plt.xlabel(r"$I_x/mA$", fontsize = 14)
plt.xlim(-1, 51)
plt.title(r'$50.0mA \quad Amperemeter $')
#plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
Ix2=np.linspace(0.00, 10.00, 26)
Is2=[1.333e-3, 0.36353, 0.73431, 1.13019, 1.53863, 1.92714, 2.3117, 2.6974, 3.1148, 3.5202, 3.9308, 4.3175, 4.7191, 5.0892, 5.4772, 5.8659, 6.2894, 6.6894, 7.0811, 7.5035, 7.9033, 8.3045, 8.7360, 9.1282, 9.5434, 9.9497]
C5=list(np.array(Is2)-np.array(Ix2))

plt.plot(Ix2, C5)
plt.scatter(Ix2, C5, c = 'k')

plt.hlines(0, -0.5, 10.5, linestyles = 'dashed', colors = 'purple')
plt.ylabel(r"$\Delta I/mA$", fontsize = 14)
plt.xlabel(r"$I_x/mA$", fontsize = 14)
plt.xlim(-0.5, 10.5)
plt.title(r'$10.0mA \quad Amperemeter $')
#plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
plt.plot(Ix1, C4, label = 'original')
plt.scatter(Ix1, C4, c = 'k', s=25, alpha = 0.5)
plt.plot(Ix1, np.array(C4)+1753/1260*Ix1/50, label = 'amended')
plt.scatter(Ix1, np.array(C4)+1753/1260*Ix1/50, c = 'k', s=25,  alpha = 0.7)

plt.hlines(0, -10, 60, linestyles = 'dashed', colors = 'purple')
plt.ylabel(r"$\Delta I/mA$", fontsize = 14)
plt.xlabel(r"$I_x/mA$", fontsize = 14)
plt.xlim(-1, 51)
plt.title(r'$50.0mA \quad Amperemeter \quad Amendment $')
plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
plt.plot(Ix2, C5, label = 'original')
plt.scatter(Ix2, C5, c = 'k', s=25, alpha = 0.5)

plt.plot(Ix2, np.array(C5)+(1753*Ix2)/(30800*10), label = 'amended')
plt.scatter(Ix2, np.array(C5)+(1753*Ix2)/(30800*10), c = 'k', s=25, alpha = 0.8)

plt.hlines(0, -1, 11, linestyles = 'dashed', colors = 'purple')
plt.ylabel(r"$\Delta I/mA$", fontsize = 14)
plt.xlabel(r"$I_x/mA$", fontsize = 14)
plt.xlim(-0.5, 10.5)
plt.title(r'$10.0mA \quad Amperemeter \quad Amendment $')
plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
plt.plot(Ux2*2, np.array(C2)*2, label = '5V')
plt.plot(Ux3, np.array(C3), label = '10V')
plt.plot(Ix2, np.array(C5)+(1753*Ix2)/(30800*10), label = '10mA amendment')
plt.plot(Ix1/5, (np.array(C4)+1753/1260*Ix1/50)/4, label = '50 mA amendment')

plt.title(r'$Correct \quad Line$')

plt.hlines(0, -1, 12, linestyles = 'dashed', colors = 'purple')
plt.vlines(1.8, -0.10, -0.02, linestyles = 'dashdot', colors = 'k')
plt.vlines(5.8, -0.12, -0.02, linestyles = 'dashdot', colors = 'k')
plt.vlines(4, -0.08, -0.02, linestyles = 'dashdot', colors = 'gray')

plt.ylim(-0.118, 0.03)
plt.xlim(-0.5, 10.5)
plt.ylabel(r'$Normalization\quad\Delta x$', fontsize = 14)
plt.xlabel(r'$Normalization \quad Unit \quad Length$', fontsize = 14)
plt.legend(frameon = False)
plt.grid()
plt.show()

# %%
from scipy import interpolate

# %%
q = interpolate.splrep(Ux2, C2, k=3)#
f = interpolate.splev(Ux2 , q)
plt.plot( Ux2, C2, 'o', Ux2 , f)
plt.show()
